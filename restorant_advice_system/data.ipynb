# %%
import pandas as pd
import selenium
import numpy as np
import matplotlib as plt

# %% [markdown]
# restornt yorumlarının birleştirilmesi

# %%
#döner yorumlarının birleşimi
df_yemeksepeti_doner=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\yemekSepeti_yorumlar\yemeksepeti_doner_yorumlar.csv")
df_trendyol_doner=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\TrendYol_yorumlar\trendyol_doner_yorumlar.csv")
df_main_doner=pd.DataFrame()
df_main_doner=pd.concat([df_yemeksepeti_doner,df_trendyol_doner],ignore_index=False)
print(df_main_doner.head())
print(df_main_doner.shape)
# Out:
#   Restoran_Adi                                              Yorum  \
# 0    Hot Döner                                         Çok iyiydi
# 1    Hot Döner  Gayet tatmin edici bir dönerdi ve içi doluydu ...
# 2    Hot Döner                                          On numara
# 3    Hot Döner  Vegan seçenek olması zaten süppeer sosunu da b...
# 4    Hot Döner  Verdiğim şipariş cok lezzetli idi fakat bir so...
#
#                                        Restoran_Link
# 0  https://www.yemeksepeti.com/restaurant/filv/ho...
# 1  https://www.yemeksepeti.com/restaurant/filv/ho...
# 2  https://www.yemeksepeti.com/restaurant/filv/ho...
# 3  https://www.yemeksepeti.com/restaurant/filv/ho...
# 4  https://www.yemeksepeti.com/restaurant/filv/ho...
# (2278, 3)

# %%
#pizza yorumların birleştirilmesi
df_yemeksepeti_pizza=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\yemekSepeti_yorumlar\yemeksepeti_pizza_yorumlar.csv")
df_trendyol_pizza=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\TrendYol_yorumlar\trendyol_pizza_yorumlar.csv")
df_main_pizza=pd.DataFrame()
df_main_pizza=pd.concat([df_trendyol_pizza,df_yemeksepeti_pizza], ignore_index= False)
print(df_main_pizza.shape)
print(df_main_pizza.head())
# Out:
# (2146, 3)
#               Restoran_Adi                                              Yorum  \
# 0  Pizza Bulls (Reşitpaşa)              Hızlı ve doğru getirdiniz teşekkürler
# 1  Pizza Bulls (Reşitpaşa)  2 saatte gelip getirdiklerinde de haber etmeye...
# 2  Pizza Bulls (Reşitpaşa)  Hem 1 saati aşkın bekledim hemde buzz gibi soğ...
# 3  Pizza Bulls (Reşitpaşa)  kola yerine ayran gondermeyi nasil basadiniz s...
# 4  Pizza Bulls (Reşitpaşa)                                        Teşekkürler
#
#                             Restoran_Link
# 0  https://tgoyemek.com/restoranlar/17346
# 1  https://tgoyemek.com/restoranlar/17346
# 2  https://tgoyemek.com/restoranlar/17346
# 3  https://tgoyemek.com/restoranlar/17346
# 4  https://tgoyemek.com/restoranlar/17346

# %%
#yorum veri setlerinin birleştirilmesi
df_main=pd.DataFrame()
df_main=pd.concat([df_main_pizza,df_main_doner],ignore_index=False)
print(df_main.shape)
print(df_main.head())
df_main.to_csv("restorant_pizza_doner_yorumları.csv",index=False ,encoding="utf-8-sig")
# Out:
# (4424, 3)
#               Restoran_Adi                                              Yorum  \
# 0  Pizza Bulls (Reşitpaşa)              Hızlı ve doğru getirdiniz teşekkürler
# 1  Pizza Bulls (Reşitpaşa)  2 saatte gelip getirdiklerinde de haber etmeye...
# 2  Pizza Bulls (Reşitpaşa)  Hem 1 saati aşkın bekledim hemde buzz gibi soğ...
# 3  Pizza Bulls (Reşitpaşa)  kola yerine ayran gondermeyi nasil basadiniz s...
# 4  Pizza Bulls (Reşitpaşa)                                        Teşekkürler
#
#                             Restoran_Link
# 0  https://tgoyemek.com/restoranlar/17346
# 1  https://tgoyemek.com/restoranlar/17346
# 2  https://tgoyemek.com/restoranlar/17346
# 3  https://tgoyemek.com/restoranlar/17346
# 4  https://tgoyemek.com/restoranlar/17346

# %% [markdown]
# restorant verilerinin birleştirilmesi

# %%
df_restorant_yemeksepeti_doner=pd.read_excel(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\YemekSeperi_Restornt_Scraping\YemekSepeti_Doner.xlsx")
df_restorant_yemeksepeti_pizza=pd.read_excel(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\YemekSeperi_Restornt_Scraping\YemekSepeti_Pizza.xlsx")
df_restorant_trendyol_doner=pd.read_excel(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\Trendyol_Scraping\TrendYol_Doner.xlsx")
df_restorant_trendyol_pizza=pd.read_excel(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\Trendyol_Scraping\TrendYol_Pizza.xlsx")

df_main_restorant=pd.concat([df_restorant_trendyol_doner,df_restorant_trendyol_pizza,df_restorant_yemeksepeti_doner,df_restorant_yemeksepeti_pizza],ignore_index=False)
print(df_main_restorant.head())
df_main_restorant.to_csv("restorant_bilgileri.csv",index=False,encoding="utf-8-sig")
print(df_main_restorant.shape)
# Out:
#                           Restoran Adı                 Puan Değ. Sayısı Durum  \
# 0                  Hot Döner (Ayazağa)                    4     (1100+)  Açık
# 1          Paşa Döner (Sarıyer Merkez)                    4      (650+)  Açık
# 2      Maydonoz Döner (Sarıyer Merkez)  2025-09-03 00:00:00      (700+)  Açık
# 3  Bİ DÖNER HATAY USÜLÜ (Sultan Selim)  2025-06-03 00:00:00       (20+)  Açık
# 4    Döner Bank Maslak Sanayi (Maslak)  2025-05-04 00:00:00      (750+)  Açık
#
#   Sponsorlu Teslimat Süresi Mesafe Min. Tutar Mutfak Değerlendirme Sayısı  \
# 0     Hayır         35-45dk  2.2km     150 TL  Döner                  NaN
# 1     Hayır         55-65dk  7.1km   1.000 TL  Döner                  NaN
# 2     Hayır         45-55dk  7.3km     650 TL  Döner                  NaN
# 3      Evet         25-35dk  3.1km     300 TL  Döner                  NaN
# 4     Hayır         15-25dk   0.7m      80 TL  Döner                  NaN
#
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# restorant bilgi veri setinin ön hazırlığı

# %%
df_restornt_bilgi=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\Software_project\restorant_advice_system\restorant_bilgileri.csv")
print(df_restornt_bilgi.columns)
# Out:
# Index(['Restoran Adı', 'Puan', 'Değ. Sayısı', 'Durum', 'Sponsorlu',
#        'Teslimat Süresi', 'Mesafe', 'Min. Tutar', 'Mutfak',
#        'Değerlendirme Sayısı', 'Fiyat Aralığı', 'Minimum Tutar',
#        'Teslimat Ücreti', 'Express', 'İnceleme Sayısı', 'Minimum Sipariş',
#        'Mutfak Tipi', 'Express Hizmeti'],
#       dtype='object')

# %%
#Değ.Sayısı , Değerlendirme ve İnceleme Sayısı başlıkları birleştirilecek
print(df_restornt_bilgi[['Değ. Sayısı','Değerlendirme Sayısı','İnceleme Sayısı']].head())
df_restornt_bilgi['degerlendirme']=df_restornt_bilgi[['Değ. Sayısı','Değerlendirme Sayısı','İnceleme Sayısı',]].astype(str).agg(' '.join ,axis=1)
print(df_restornt_bilgi['degerlendirme'].shape)
# Out:
#   Değ. Sayısı Değerlendirme Sayısı İnceleme Sayısı
# 0     (1100+)                  NaN             NaN
# 1      (650+)                  NaN             NaN
# 2      (700+)                  NaN             NaN
# 3       (20+)                  NaN             NaN
# 4      (750+)                  NaN             NaN
# (250,)
